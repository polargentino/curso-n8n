# %% [markdown]
# Hola, aquí tienes el contenido que solicitaste, formateado para que quepa en una hoja A4, ideal para imprimir o ver como un documento profesional. He optimizado la estructura para que sea clara y fácil de seguir, con un diseño limpio y directo.
#
# -----
#
# # 🚀 Construyendo un mini-flujo de trabajo en n8n
#
# En esta guía, aprenderás a crear un flujo de trabajo simple para obtener 10 artículos sobre automatización desde Hacker News. Sigue estos 5 pasos para completarlo.
#
# ## 1\. Agregar un nodo de activación manual
#
# El nodo **Activador manual** es el punto de inicio de tu flujo de trabajo. Puedes agregarlo abriendo el panel de nodos con `+` o `Tab` y buscando "Activador manual". Esto te permitirá ejecutar el flujo de trabajo en cualquier momento con el botón **Ejecutar flujo de trabajo**.
#
# > **Nota:** Para flujos más rápidos, puedes omitir este paso en el futuro, ya que n8n lo añade automáticamente al agregar un nodo sin disparador. En un escenario real, usarías un **disparador** programado.
#
# ## 2\. Añadir y configurar el nodo de Hacker News
#
# Este nodo es el que hará la magia de obtener los artículos.
#
# 1.  Abre el panel de nodos con `+` a la derecha del nodo anterior.
# 2.  Busca y selecciona el nodo **Hacker News**.
# 3.  En la sección de **Acciones**, selecciona **Obtener muchos elementos**.
# 4.  El nodo se añadirá al lienzo y se abrirán sus detalles de configuración.
#
# ### Parámetros del nodo Hacker News
#
# Los **parámetros** son específicos para cada nodo. Configura los siguientes:
#
#   * **Recurso:** Todos (selecciona todos los registros de datos).
#   * **Operación:** Obtener muchos (recupera los artículos seleccionados).
#   * **Límite:** 10 (establece la cantidad de resultados).
#   * **Campos adicionales \> Añadir campo \> Palabra clave:** automatización (filtra los resultados para incluir solo esta palabra).
#
# ### Configuración del nodo
#
# Las **configuraciones** son opciones comunes a todos los nodos. Te recomiendo configurar las notas para que tu flujo sea más claro:
#
#   * **Notas:** Obtenga los 10 últimos artículos.
#   * **¿Mostrar nota en el flujo?:** Alternar a **verdadero**.
#
# ## 3\. Ejecutar el nodo y revisar los resultados
#
# Una vez configurado el nodo, puedes probarlo.
#
# 1.  Selecciona el botón **Ejecutar paso** en la ventana de configuración del nodo.
# 2.  Si la ejecución es exitosa, verás una marca de verificación verde en el nodo del lienzo.
# 3.  Los resultados se mostrarán en la ventana en formato de **Tabla** (predeterminado), **JSON** y **Esquema**. Puedes alternar entre ellos.
# 4.  Junto al título de la **Salida**, puedes ver la **Hora de inicio** y el **Tiempo de ejecución**, así como la cantidad de elementos devueltos (en este caso, 10).
#
# > **Nota:** Si un nodo tiene errores (credenciales faltantes o parámetros incorrectos), mostrará un ícono de advertencia rojo.
#
# ## 4\. Guardar el flujo de trabajo
#
# El flujo de trabajo se guarda automáticamente con el nombre "Mi flujo de trabajo". Para que sea más claro:
#
# 1.  Haz clic en el nombre del flujo de trabajo en la parte superior de la interfaz.
# 2.  Cámbialo a "Flujo de trabajo de Hacker News".
# 3.  Guárdalo manualmente presionando `Ctrl + S` o `Cmd + S`, o haciendo clic en el botón **Guardar**. Si ves "Guardado", significa que ya se guardó automáticamente.
#
# ## 5\. El flujo de trabajo terminado
#
# Tu flujo de trabajo debería verse de esta manera, listo para ser ejecutado:
#
# ```
# [Activador manual]
#           ↓
# [Hacker News]
# ```
#
# Espero que esta guía concisa sea perfecta para tu necesidad. ¿Te gustaría que te ayude con otro documento o proceso?
