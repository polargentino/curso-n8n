# %% [markdown]
# Aquí tienes la versión actualizada del documento, con la terminología de n8n en inglés y su traducción al español, tal como se muestra en la interfaz.
#
# -----
#
# # 🚀 Construyendo un mini-flujo de trabajo en n8n
#
# En esta guía, crearás un flujo de trabajo simple para obtener 10 artículos sobre automatización desde Hacker News. Sigue estos 5 pasos para completarlo.
#
# ## 1\. Agregar un nodo de activación manual
#
# El nodo **Manual Trigger** (Disparador manual) es el punto de inicio de tu flujo de trabajo. Puedes agregarlo abriendo el panel de nodos con el ícono `+` o presionando `Tab` en tu teclado. Esto te permitirá ejecutar el flujo en cualquier momento con el botón **Execute workflow** (Ejecutar flujo de trabajo).
#
# > **Nota:** Para flujos más rápidos, puedes omitir este paso en el futuro, ya que n8n lo añade automáticamente al agregar un nodo sin disparador. En un escenario real, usarías un **Trigger** (Disparador) programado.
#
# -----
#
# ## 2\. Añadir y configurar el nodo de Hacker News
#
# Este nodo es el que hará la magia de obtener los artículos.
#
# 1.  Abre el panel de nodos con el ícono `+` a la derecha del nodo anterior.
# 2.  Busca y selecciona el nodo **Hacker News**.
# 3.  En la sección de **Actions** (Acciones), selecciona **Get Many Items** (Obtener muchos elementos).
# 4.  El nodo se añadirá al lienzo y se abrirán sus detalles de configuración.
#
# ### Parámetros del nodo
#
# Los **Parameters** (Parámetros) son específicos para cada nodo. Configura los siguientes:
#
#   * **Resource** (Recurso): All (Todos)
#   * **Operation** (Operación): Get Many (Obtener muchos)
#   * **Limit** (Límite): 10
#   * **Additional Fields** (Campos adicionales) \> **Add Field** (Añadir campo) \> **Keyword** (Palabra clave): automatización
#
# ### Configuración del nodo
#
# Las **Settings** (Configuraciones) son opciones comunes a todos los nodos. Te recomiendo configurar las notas para que tu flujo sea más claro:
#
#   * **Notes** (Notas): Obtenga los 10 últimos artículos.
#   * **Show note on the canvas?** (¿Mostrar nota en el flujo?): Alternar a verdadero.
#
# -----
#
# ## 3\. Ejecutar el nodo y revisar los resultados
#
# Una vez configurado, puedes probar el nodo.
#
# 1.  Selecciona el botón **Run Step** (Ejecutar paso) en la ventana del nodo.
# 2.  Si la ejecución es exitosa, verás una marca de verificación verde en el nodo del lienzo.
# 3.  Los resultados se mostrarán en la ventana en formato de **Table** (Tabla), **JSON** y **Schema** (Esquema).
# 4.  Junto al título de la **Output** (Salida), puedes ver la **Start Time** (Hora de inicio) y la **Execution Time** (Tiempo de ejecución), así como la cantidad de **items** (elementos) devueltos.
#
# > **Nota:** Si un nodo tiene errores (credenciales faltantes o parámetros incorrectos), mostrará un ícono de advertencia rojo.
#
# -----
#
# ## 4\. Guardar el flujo de trabajo
#
# Tu flujo de trabajo se guarda automáticamente como **My workflow** (Mi flujo de trabajo). Para un nombre más descriptivo:
#
# 1.  Haz clic en el nombre del flujo de trabajo en la parte superior de la interfaz.
# 2.  Cámbialo a "Flujo de trabajo de Hacker News".
# 3.  Guarda los cambios con **Save** (Guardar) o presionando `Ctrl + S`.
#
# -----
#
# ## 5\. El flujo de trabajo terminado
#
# Tu flujo de trabajo terminado se verá de esta manera, listo para ser ejecutado:
#
# ```
# [Manual Trigger]
#           ↓
# [Hacker News]
# ```
