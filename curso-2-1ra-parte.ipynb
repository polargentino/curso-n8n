# %% [markdown]
# # Respuestas del Cuestionario Basadas en el Flujo de Trabajo (Workflow)
#
# Este documento resume las respuestas exactas extraídas de los logs de la ejecución de tu flujo de trabajo de integración de datos (Airtable + REST Countries API).
#
# ---
#
# ## Preguntas y Respuestas
#
# | Pregunta | Respuesta Correcta |
# | :--- | :--- |
# | **1. ¿Cuántos ítems devuelve el nodo HTTP Request?** | **250 ítems** (El total de países devueltos por la API). |
# | **2. ¿Cuántos ítems devuelve el nodo Merge?** | **10 ítems** (El número de clientes de Airtable para los cuales se encontró una coincidencia de país en la API). |
# | **3. ¿Cuántas regiones únicas se asignan en la tabla de clientes?** | **4 regiones únicas** (Oceania, Europe, Americas, Asia). |
# | **4. ¿Cuál es la subregión asignada al customerID 10?** | **Caribbean** (Caribe). |
#
# ---
#
# ## 🌎 Detalle de Regiones Únicas Asignadas
#
# Las **4 regiones únicas** asignadas a los clientes que lograron fusionarse son:
#
# 1.  **Oceania** (Australia)
# 2.  **Europe** (Francia, Alemania, Reino Unido)
# 3.  **Americas** (Brasil, Canadá, Cuba, Estados Unidos)
# 4.  **Asia** (Japón, China)
#
# ***
# ```
#
# -----
#
# Espero que este archivo .md te sea útil para documentar tu proyecto. ¿Hay alguna otra parte de este flujo de trabajo que te gustaría documentar o un nuevo desafío que quieras abordar?
