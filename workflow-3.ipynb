# %% [markdown]
# Perfecto! 🔑 Ese es el Client Secret nuevo que generaste en Google Cloud. Ahora sí, con ese dato podemos cerrar el circuito en n8n.
#
# 📌 Checklist rápido para que funcione
#
# En Google Cloud Console ya tenés:
#
# Client ID → 462638838014-uo7d...apps.googleusercontent.com
#
# Client Secret → ****O85y
#
# Redirect URI autorizado → http://localhost:5678/rest/oauth2-credential/callback
#
# Origen autorizado de JS → http://localhost:5678
#
# Usuario de prueba agregado → polargentino@gmail.com
#
# ✔️ Todo correcto.
#
# En n8n → Credenciales Gmail
#
# Tipo: OAuth2
#
# Client ID → pega el de Google
#
# Client Secret → pega el nuevo (****O85y)
#
# Redirect URI (n8n te lo muestra) → tiene que coincidir con el que pusiste en Google
#
# Scopes → añade al menos:
#
# https://mail.google.com/
# https://www.googleapis.com/auth/gmail.send
#
#
# OAuth2 Flow → Web Application
#
# Auth URL:
#
# https://accounts.google.com/o/oauth2/auth
#
#
# Token URL:
#
# https://oauth2.googleapis.com/token
#
#
# Probar conexión
#
# Guardá la credencial en n8n.
#
# Hacé clic en Connect → te debería abrir la ventana de Google para loguearte con polargentino@gmail.com.
#
# Aceptás los permisos → vuelve a n8n con el token guardado.
#
# Ejecutar el flujo
#
# Volvé al nodo Gmail.
#
# Ejecutá el workflow.
#
# Si todo está OK, el correo de prueba debería salir sin el error Client authentication failed.

# %% [markdown]
# 🔥 Bien ahí, ahora ya está guardada y conectada tu credencial Gmail OAuth2 en n8n. Eso significa que la parte más complicada (Google OAuth) ya la resolviste ✅.
#
# Ahora te resumo lo que falta para que el envío funcione:
#
# ✔ Checklist para enviar un correo
#
# Credencial Gmail: ✅ ya conectada.
#
# Nodo Gmail: Configuralo así:
#
# Resource → Message
#
# Operation → Send
#
# To → escribe directamente un correo (ejemplo: tucorreo@ejemplo.com)
#
# Subject → Prueba desde n8n
#
# Email Type → Text
#
# Message → Hola — este es un correo de prueba enviado desde n8n.
#
# Ejecutar nodo → Click en Execute Node.
