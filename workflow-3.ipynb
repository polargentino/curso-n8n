# %% [markdown]
# Perfecto! 🔑 Ese es el Client Secret nuevo que generaste en Google Cloud. Ahora sí, con ese dato podemos cerrar el circuito en n8n.
#
# 📌 Checklist rápido para que funcione
#
# En Google Cloud Console ya tenés:
#
# Client ID → 462638838014-uo7d...apps.googleusercontent.com
#
# Client Secret → ****O85y
#
# Redirect URI autorizado → http://localhost:5678/rest/oauth2-credential/callback
#
# Origen autorizado de JS → http://localhost:5678
#
# Usuario de prueba agregado → polargentino@gmail.com
#
# ✔️ Todo correcto.
#
# En n8n → Credenciales Gmail
#
# # 📧 Configuración Gmail OAuth2 en n8n
# Guía paso a paso para conectar **n8n** con Gmail y enviar un correo de prueba.
# Todo explicado de forma simple para que funcione sin errores.
#
# ---
#
# ## 🔑 Configuración en Google Cloud Console
#
# 1. **Datos creados en tu proyecto:**
#    - **Client ID:**
#      `462638838014-uo7d...apps.googleusercontent.com`
#    - **Client Secret:**
#      `****O85y`
#    - **Redirect URI autorizado:**
#      `http://localhost:5678/rest/oauth2-credential/callback`
#    - **Origen autorizado de JS:**
#      `http://localhost:5678`
#    - **Usuario de prueba agregado:**
#      `polargentino@gmail.com`
#
# ✅ Todo correcto en Google.
#
# ---
#
# ## ⚙️ Configuración en n8n (Credenciales Gmail)
#
# 1. **Tipo:** `OAuth2`
# 2. **Client ID:** pega el de Google.
# 3. **Client Secret:** pega el nuevo (`****O85y`).
# 4. **Redirect URI:** usa el que te muestra n8n (debe coincidir con Google).
# 5. **Scopes necesarios:**
#
#
# https://mail.google.com/
#
# https://www.googleapis.com/auth/gmail.send
#
#
#
# 6. **OAuth2 Flow:** `Web Application`
# 7. **Auth URL:**
# `https://accounts.google.com/o/oauth2/auth`
# 8. **Token URL:**
# `https://oauth2.googleapis.com/token`
#
# ---
#
# ## 🔗 Conectar la cuenta
#
# 1. Guardá la credencial en n8n.
# 2. Hacé clic en **Connect**.
# 3. Se abre la ventana de Google → logueate con `polargentino@gmail.com`.
# 4. Aceptá los permisos.
# 5. Vuelve a n8n → el token queda guardado.
#
# 🔥 ¡Listo! La credencial Gmail OAuth2 ya está conectada.
# Esto resuelve la parte más complicada: el **OAuth con Google** ✅.
#
# ---
#
# ## ✉️ Enviar un correo de prueba en n8n
#
# 1. **Abrí el nodo Gmail**.
# 2. Configuralo así:
# - **Resource:** `Message`
# - **Operation:** `Send`
# - **To:** `tucorreo@ejemplo.com`
# - **Subject:** `Prueba desde n8n`
# - **Email Type:** `Text`
# - **Message:**
#   ```
#   Hola — este es un correo de prueba enviado desde n8n.
#   ```
#
# 3. Dale clic en **Execute Node**.
#
# ✅ Si todo está OK, el correo debería llegar sin mostrar
# `Client authentication failed`.
#
# ---
#
# ## 📝 Resumen rápido
#
# - **Google Cloud:** credenciales creadas y usuario de prueba agregado.
# - **n8n:** credencial Gmail conectada vía OAuth2.
# - **Nodo Gmail:** configurado en modo *Send Message*.
# - **Prueba:** correo enviado correctamente 🚀.
