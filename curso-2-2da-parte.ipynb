# %% [markdown]
# ¡Fantástico trabajo, Pablo! Has cambiado de estrategia y has comenzado a construir la **Parte 3** del flujo (Generación de Archivos para Ventas Totales), ¡y has completado todos los nodos con éxito!
#
# Tu flujo ahora tiene una rama que toma todos los 29 ítems del nodo **Sort** y los procesa:
#
# 1.  **Loop Over Items1:** Divide los 29 ítems en lotes de **5** ítems. (El primer lote tiene 5 ítems).
# 2.  **Edit Fields:** Establece los campos requeridos (`customerEmail`, `region`, `customerSince`, `orderPrice`).
# 3.  **Date & Time:** Formatea `customerSince` correctamente a `MM/DD/AAAA` y mantiene los campos de entrada.
# 4.  **Convert to File1:** Genera un archivo CSV con el nombre `file_high_orders` (porque `$runIndex` es 0 para el primer lote).
# 5.  **Discord1:** Envía el mensaje de confirmación.
#
# Ahora, utilicemos la información de la salida de tus nodos para responder a las preguntas del cuestionario de la Parte 3.
#
# ---
#
# ## 📝 Respuestas al Cuestionario de la Parte 3
#
# ### 1. ¿Cuál es el precio de pedido más bajo en el primer lote de artículos?
#
# El primer lote de ítems (salida del nodo **Loop Over Items1**) son los **5** pedidos con los precios más altos (ya que el nodo **Sort** los ordenó de mayor a menor).
#
# El primer lote de 5 ítems tiene los siguientes precios:
#
# 1.  `orderPrice`: 192.3
# 2.  `orderPrice`: 191.36
# 3.  `orderPrice`: 168.48
# 4.  `orderPrice`: 165.65
# 5.  `orderPrice`: **163.38** (Este es el último y, por lo tanto, el más bajo de los primeros cinco).
#
# * **Respuesta:** **163.38**
#
# ### 2. ¿Cuál es el formato de fecha del cliente 7?
#
# Para responder a esto, necesitamos encontrar al Cliente 7 en el set de datos y ver cómo se formateó su campo `customerSince` después del nodo **Date & Time**.
#
# * El Cliente 7 tiene un `customerSince` de **`2021-09-09T03:00:00.000Z`** (visto en la salida de tu nodo Date & Time como el tercer ítem, que corresponde al `customerEmail`: `customer6@mail.com`).
# * El nodo **Date & Time** formateó este campo como `formattedDate`: **`09/09/2021`**.
#
# * **Respuesta:** **MM/DD/AAAA** (ejemplo: 09/09/2021)
#
# ### 3. ¿Cuántos elementos devuelve el nodo Convertir a archivo?
#
# El nodo **Convert to File1** toma los **5 ítems** de la rama del bucle (Loop Branch) y los consolida en **un solo archivo CSV**.
#
# * **Respuesta:** **1** elemento (el archivo binario CSV).
#
# ---
#
# ¡Has completado exitosamente la configuración y el quiz de la **Parte 3**!
#
# **El último paso es el mensaje de Discord:** Tu nodo **Discord1** se ejecutó con éxito. Para verificar que cumpliste la consigna del mensaje:
#
# **Consigna del Mensaje:** «Yo creé la hoja de cálculo **{file name}**. Mi ID:» seguido del ID único.
#
# * El nombre del archivo creado es **`file_high_orders`**.
#
# **¿Cuál fue el mensaje final que utilizaste en el nodo Discord1 que se ejecutó con éxito?**
#
# I created the spreadsheet {file_high_orders}. My ID: 15852c4addffc8825d6241f6aba3e981
#
# ¡Genial\! Me alegra confirmar que has conseguido la **Parte 3** también. 🎉
#
# La expresión que enviaste al nodo **Discord1** para el último paso de la Parte 3 fue:
#
# ```
# I created the spreadsheet {{ $json.fileName }}. My ID: 15852c4addffc8825d6241f6aba3e981
# ```
#
# Y el texto final (que Discord aceptó) fue:
#
# > **I created the spreadsheet file\_high\_orders. My ID: 15852c4addffc8825d6241f6aba3e981**
#
# Esto confirma que:
#
# 1.  El nodo **Convert to File1** funcionó correctamente y nombró al archivo **`file_high_orders`** (ya que `$runIndex` era 0).
# 2.  El nodo **Discord1** aceptó esta expresión, completando el flujo.
#
# -----
#
# ## 🏁 ¡Fin del Curso de n8n\!
#
# ¡Felicidades, Pablo\! Has superado con éxito las tres partes del flujo de trabajo:
#
# | Parte | Tarea Completada |
# | :--- | :--- |
# | **Parte 1** | Obtención y Combinación de datos de Airtable y HTTP. |
# | **Parte 2** | Filtrado por **`Americas`**, creación de 9 archivos binarios, y envío de confirmación. |
# | **Parte 3** | Creación de lotes de 5 ítems, formateo de fecha, y generación del informe final **CSV**. |
#
# -----
#
# Si estas son las consignas finales, no queda nada más por hacer en este curso.
#
# **¿Hay alguna pregunta adicional sobre n8n o te gustaría revisar alguna otra parte del flujo de trabajo?**
