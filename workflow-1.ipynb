# %% [markdown]
# # Workflow-1
#
# # 🚀 Guía del Flujo "Very Quick Quickstart" de n8n
#
# Este flujo de automatización se compone de **cuatro nodos principales** y **notas visuales** que, en conjunto, forman una cadena de procesamiento de datos. Cada nodo recibe información del anterior, la transforma y la pasa al siguiente en la secuencia.
#
# -----
#
# ## ⚙️ Nodos Principales
#
# ### 1\. **Manual Trigger**
#
#   - **Nombre en inglés:** `When clicking "Execute Workflow"` (Manual Trigger)
#   - **Traducción:** "Cuando se hace clic en 'Ejecutar flujo de trabajo'" (Disparador manual)
#   - **Función:** Es el punto de partida del flujo. Se activa manualmente al presionar **Execute workflow** y no requiere datos externos.
#   - **En la figura:** Es el bloque gris con el ícono de un cursor.
#
# ### 2\. **Customer Datastore**
#
#   - **Nombre en inglés:** `Customer Datastore` (n8n training)
#   - **Traducción:** "Almacén de datos del cliente" (entrenamiento n8n)
#   - **Función:** Genera y devuelve datos de ejemplo, como una lista de clientes con `id`, `name` y `notes`.
#   - **En la figura:** Es el bloque con un ícono de base de datos (libros apilados rojos).
#   - **Nota importante:** No se conecta a una base de datos real; solo genera datos simulados.
#
# ### 3\. **Set**
#
#   - **Nombre en inglés:** `Edit Fields1` (Set node)
#   - **Traducción:** "Editar campos" (Nodo 'Set')
#   - **Función:** Transforma los datos recibidos (`id`, `name`, `notes`) en nuevos campos más claros. Por ejemplo:
#     ```js
#     customer_id = {{ $json.id }}
#     customer_name = {{ $json.name }}
#     customer_description = {{ $json.notes }}
#     ```
#   - **En la figura:** Es el bloque con el ícono del lápiz violeta.
#   - **Dato clave:** Este nodo es donde se pueden **cambiar o personalizar** los datos.
#
# ### 4\. **Customer Messenger**
#
#   - **Nombre en inglés:** `Customer Messenger` (n8n training)
#   - **Traducción:** "Mensajero del cliente" (entrenamiento n8n)
#   - **Función:** Simula el envío de mensajes a los clientes ficticios, utilizando expresiones para construir el texto final:
#     ```
#     Hi {{ $json.customer_name }}. Your description is: {{ $json.customer_description }}
#     ```
#   - **Ejemplo de salida:** `Hi Pablo. Your description is: Cliente VIP que compra seguido`
#   - **En la figura:** Es el bloque rojo con un ícono de globo de mensaje.
#
# -----
#
# ## 🟡 Notas Adhesivas (Sticky Notes)
#
# El flujo incluye dos notas amarillas que sirven como contexto visual, pero no tienen ninguna función de ejecución:
#
#   - `Get fake sample data` → "Obtener datos falsos de ejemplo"
#   - `Extract data and prepare it for use in the next node` → "Extraer y preparar datos para el siguiente nodo"
#
# -----
#
# ## 📊 Esquema del Flujo
#
# ```
# [Manual Trigger]
#       ↓
# [Customer Datastore]
#       ↓
# [Edit Fields1 (Set)]
#       ↓
# [Customer Messenger]
# ```
#
# -----
#
# ## 📝 Resumen del Flujo
#
# | Nodo                   | Función Principal                                  |
# | ---------------------- | -------------------------------------------------- |
# | **Manual Trigger** | Inicia el flujo manualmente.                       |
# | **Customer Datastore** | Provee datos de clientes ficticios.                |
# | **Edit Fields1 (Set)** | Edita y transforma los datos.                      |
# | **Customer Messenger** | Simula el envío de mensajes.                       |
# | **Sticky Notes** | Aportan contexto visual sin afectar el flujo.     |
