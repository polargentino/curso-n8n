# %% [markdown]
# Hola. Con mucho gusto, aquí tienes la información que me proporcionaste, pero formateada de una manera más profesional y visualmente atractiva para tu archivo `.ipynb`.
#
# He simplificado el texto, usado una tipografía de código uniforme para los ejemplos y organizado los contenidos para que sea fácil de leer y copiar.
#
# -----
#
# # 🚀 Guía Rápida del Flujo de n8n
#
# Este documento describe el flujo “Very Quick Quickstart” de n8n, un proceso automatizado compuesto por cuatro nodos principales. Cada nodo realiza una función específica, procesando y pasando datos al siguiente, creando una cadena de tareas lógicas.
#
# -----
#
# ## ⚙️ Descripción de los Nodos
#
# ### 1\. **Manual Trigger**
#
#   - **Función:** Es el punto de inicio del flujo. Este nodo no requiere datos externos; se activa manualmente al hacer clic en **Execute Workflow**.
#   - **Ícono:** Bloque gris con un cursor.
#
# ### 2\. **Customer Datastore**
#
#   - **Función:** Genera datos de prueba. Devuelve una lista de clientes ficticios con los campos `id`, `name`, y `notes`.
#   - **Importante:** No se conecta a una base de datos real.
#   - **Ícono:** Base de datos (libros apilados).
#
# ### 3\. **Set (Edit Fields1)**
#
#   - **Función:** Transforma y personaliza los datos recibidos. Este nodo crea campos más claros para el siguiente paso, como se muestra en el siguiente ejemplo:
#     ```js
#     customer_id = {{ $json.id }}
#     customer_name = {{ $json.name }}
#     customer_description = {{ $json.notes }}
#     ```
#   - **Ícono:** Bloque con un lápiz violeta.
#
# ### 4\. **Customer Messenger**
#
#   - **Función:** Simula el envío de mensajes a los clientes ficticios. Utiliza las expresiones definidas en el nodo `Set` para construir un mensaje final.
#   - **Ejemplo de salida:** `Hi Pablo. Your description is: Cliente VIP que compra seguido`
#   - **Ícono:** Bloque rojo con un globo de mensaje.
#
# -----
#
# ## 🟡 Notas Adhesivas (Sticky Notes)
#
# El flujo también incluye notas visuales que no afectan la ejecución, solo sirven como recordatorios o explicaciones:
#
#   - `Get fake sample data` (Obtener datos falsos de ejemplo)
#   - `Extract data and prepare it for use in the next node` (Extraer y preparar datos para el siguiente nodo)
#
# -----
#
# ## 🔗 Estructura del Flujo
#
# ```
# [Manual Trigger]
#        ↓
# [Customer Datastore]
#        ↓
# [Edit Fields1 (Set)]
#        ↓
# [Customer Messenger]
# ```
#
# -----
#
# ## 📋 Resumen Rápido
#
# | Nodo                   | Función Principal                                     |
# | ---------------------- | ----------------------------------------------------- |
# | **Manual Trigger** | Inicia el flujo manualmente.                          |
# | **Customer Datastore** | Provee datos de clientes ficticios para pruebas.      |
# | **Edit Fields1 (Set)** | Transforma y edita los datos.                         |
# | **Customer Messenger** | Simula el envío de mensajes usando los datos transformados. |
# | **Sticky Notes** | Aportan contexto visual sin afectar el flujo.         |
#
# -----
#
# Espero que esta versión te sirva para tu archivo `.ipynb`. ¿Te gustaría que te ayude a formatear alguna otra cosa?
